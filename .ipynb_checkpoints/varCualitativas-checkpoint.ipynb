# %% [markdown]
# ![Texto Alternativo](logoitqv1.jpg)

# %% [markdown]
# #### 0.1 01PAO26-26 - Variables cualitativas

# %% [markdown]
# ![Texto Alternativo](python_logo.png)

# %% [markdown]
# * Nombre: Martin Sosa
# * Fecha:  **13-07-2026**
# * Repositorio: <a href="https://github.com/Martin122334/machine2026nocturno">Link del repositorio de Github</a>

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)
nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Secundaria' 'Master' 'Master' 'Master' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Master' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Grado' 'Master' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Master' 'Grado' 'Master' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Master' 'Grado' 'Secundaria' 'Doctorado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Grado' 'Master' 'Doctorado' 'Doctorado' 'Bachillerato' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Doctorado' 'Secundaria' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Master' 'Grado' 'Grado'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Grado'
#  'Doctorado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Grado' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master' 'Master'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Doctorado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Doctorado' 'Grado' 'Master'
#  'Grado' 'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Doctorado' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Master' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Doctorado' 'Secundaria' 'Secundaria' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np

# %%
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Serie de datos con Pandas
df_estudios = pd.Series(nivel_estudios, name="Nivel_Estudios")

#frecuencias absolutas ordenadas
frecuencias = df_estudios.value_counts()
print("Frecuencias absolutas:")
print(frecuencias)


plt.figure(figsize=(8, 5))
frecuencias.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Diagrama de barras (Pandas)")
plt.xlabel("Nivel de estudios")
plt.ylabel("Frecuencia absoluta")
plt.xticks(rotation=0)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

colores = ["orange", "green", "blue", "cyan", "red"]

plt.figure(figsize=(6, 6))
frecuencias.plot(
    kind="pie",
    autopct="%1.2f%%",
    colors=colores,
    startangle=0,
    ylabel="",  
)
plt.title("Diagrama de sectores (Pandas)")
plt.show()
# Out:
# Frecuencias absolutas:
# Nivel_Estudios
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64
